# %%
from google.colab import drive

# %% [markdown]
# 아래 명령 실행 후, URL이 나오면 click한 후 나오는 authorization code를 아래 입력칸에 입력후 enter

# %%
import os
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

# %%
cd /content/drive/'My Drive'

# %%
if not os.path.exists('TensorFlow_Training_16th'):
  # !git clone https://github.com/jwlee-ml/TensorFlow_Training_16th.git

# %%
cd TensorFlow_Training_16th

# %%
# !git pull
